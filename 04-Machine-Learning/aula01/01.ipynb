# %%
#abrir csv com pandas 'https://raw.githubusercontent.com/lcbjrrr/quant/master/covid_br%20-%20ok.csv'
import pandas as pd
import numpy as np

# %%
cov = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/quant/master/covid_br%20-%20ok.csv')
cov.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/11/21  4/12/21  4/13/21  \
# 0        0        0        0        0  ...    57160    57242    57364
# 1        0        0        0        0  ...   128393   128518   128752
# 2        0        0        0        0  ...   118516   118645   118799
# 3        0        0        0        0  ...    12545    12581    12614
# 4        0        0        0        0  ...    23457    23549    23697
#
#    4/14/21  4/15/21  4/16/21  4/17/21  4/18/21  4/19/21  4/20/21
# ...

# %%
br = cov[cov['Country/Region']=='Brazil']
brasil = br.T[4:]
brasil.diff().rolling(14).mean().plot()
# Out:
# <Axes: >
